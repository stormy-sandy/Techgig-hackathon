# %%
''''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "'from google.colab import drive\ndrive.mount('/content/drive')"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', -1)

# %%
work_data=pd.read_csv('Hackathon_Working_Data.csv')
work_data.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0  M1    N1        4    T375    225.0     1.0  225.0  225.0
# 1  M1    N1        4    T379    95.0      1.0  95.0   95.0
# 2  M1    N1        4    T381    10.0      1.0  10.0   10.0
# 3  M1    N1        4    T382    108.0     1.0  108.0  108.0
# 4  M1    N1        4    T384    19.0      1.0  19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0  BUTTER MARGR  (4/94)     BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2  CHOCOLATE                CHOCOLATE PANNED         CHOCOLATE PANNED
# 3  PACKAGED TEA             MAIN PACKS               MAIN PACKS
# 4  ALL IODISED SALT         POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0  G C M M F               AMUL           AMUL
# 1  PARLE PRODS             MELODY         MELODY CHOCOLATY
# ...

# %%
work_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
# MONTH        26985 non-null object
# STORECODE    26985 non-null object
# DAY          26985 non-null int64
# BILL_ID      26985 non-null object
# BILL_AMT     26985 non-null float64
# QTY          26985 non-null float64
# VALUE        26985 non-null float64
# PRICE        26985 non-null float64
# GRP          26985 non-null object
# SGRP         26985 non-null object
# SSGRP        26985 non-null object
# CMP          26985 non-null object
# MBRD         26985 non-null object
# BRD          26985 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
val_data=pd.read_csv('Hackathon_Validation_Data.csv')
val_data.head()
# Out:
#         ID STORECODE MONTH                       GRP
# 0  1112535  N1        M1    AFTER SHAVE LOTIONS
# 1  1112539  N1        M1    AGARBATTI & DHOOPBATTI
# 2  1112543  N1        M1    ALL AIR FRESHNERS(01/03)
# 3  1112547  N1        M1    ALL IODISED SALT
# 4  1112551  N1        M1    ANTACIDS

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 4 columns):
# ID           2430 non-null int64
# STORECODE    2430 non-null object
# MONTH        2430 non-null object
# GRP          2430 non-null object
# dtypes: int64(1), object(3)
# memory usage: 76.1+ KB

# %%
ideal_data=pd.read_csv('Hackathon_Ideal_Data.csv')
ideal_data.head()
# Out:
#   MONTH STORECODE  QTY  VALUE                GRP               SGRP  \
# 0  M1    P1        25   83     HAIR CONDITIONERS  HAIR CONDITIONERS
# 1  M1    P1        6    22     HAIR CONDITIONERS  HAIR CONDITIONERS
# 2  M1    P1        4    15     HAIR CONDITIONERS  HAIR CONDITIONERS
# 3  M1    P1        15   60     HAIR CONDITIONERS  HAIR CONDITIONERS
# 4  M1    P2        0    0      HAIR CONDITIONERS  HAIR CONDITIONERS
#
#                SSGRP                         CMP         MBRD  \
# 0  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  DOVE
# 1  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  DOVE
# 2  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  DOVE
# 3  HAIR CONDITIONERS  L'OREAL INDIA               GARNIER
# 4  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  CLINIC PLUS
#
#                      BRD
# 0  DOVE HAIR FALL RESCUE
# 1  DOVE INTENSE REPAIR
# 2  DOVE OXYGEN MOISTURE
# 3  FRUCTIS
# 4  CLINIC PLUS

# %%
#ideal_data.info()

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 4 columns):
# ID           2430 non-null int64
# STORECODE    2430 non-null object
# MONTH        2430 non-null object
# GRP          2430 non-null object
# dtypes: int64(1), object(3)
# memory usage: 76.1+ KB

# %%
work_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
# MONTH        26985 non-null object
# STORECODE    26985 non-null object
# DAY          26985 non-null int64
# BILL_ID      26985 non-null object
# BILL_AMT     26985 non-null float64
# QTY          26985 non-null float64
# VALUE        26985 non-null float64
# PRICE        26985 non-null float64
# GRP          26985 non-null object
# SGRP         26985 non-null object
# SSGRP        26985 non-null object
# CMP          26985 non-null object
# MBRD         26985 non-null object
# BRD          26985 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
unique, counts = np.unique(ideal_data.STORECODE, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'P1': 1061,
#  'P10': 1508,
#  'P2': 1471,
#  'P3': 1362,
#  'P4': 1454,
#  'P5': 627,
#  'P6': 2097,
#  'P7': 850,
#  'P8': 2642,
#  'P9': 1188}

# %%
 di = {'P1': 'N1',
 'P10':'N10' ,
 'P2': 'N2',
 'P3': 'N3',
 'P4': 'N4',
 'P5': 'N5',
 'P6': 'N6',
 'P7': 'N7',
 'P8': 'N8',
 'P9': 'N9'}

# %%
ideal_data['STORECODE']=ideal_data['STORECODE'].map(di)

# %%
ideal_data['VALUE']=ideal_data['VALUE'].astype('int32')

# %%
ideal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14260 entries, 0 to 14259
# Data columns (total 10 columns):
# MONTH        14260 non-null object
# STORECODE    14260 non-null object
# QTY          14260 non-null int64
# VALUE        14260 non-null int32
# GRP          14260 non-null object
# SGRP         14260 non-null object
# SSGRP        14260 non-null object
# CMP          14260 non-null object
# MBRD         14260 non-null object
# BRD          14260 non-null object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 1.0+ MB

# %%
work_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
# MONTH        26985 non-null object
# STORECODE    26985 non-null object
# DAY          26985 non-null int64
# BILL_ID      26985 non-null object
# BILL_AMT     26985 non-null float64
# QTY          26985 non-null float64
# VALUE        26985 non-null float64
# PRICE        26985 non-null float64
# GRP          26985 non-null object
# SGRP         26985 non-null object
# SSGRP        26985 non-null object
# CMP          26985 non-null object
# MBRD         26985 non-null object
# BRD          26985 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
ideal_data=ideal_data.drop(['SGRP','SSGRP','CMP','MBRD','BRD','QTY'],axis=1)

#work_data=work_data.drop(['DAY','BILL_AMT','BILL_ID','SGRP','SSGRP','CMP','MBRD','BRD','PRICE','QTY'],axis=1)

# %%
work_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
# MONTH        26985 non-null object
# STORECODE    26985 non-null object
# DAY          26985 non-null int64
# BILL_ID      26985 non-null object
# BILL_AMT     26985 non-null float64
# QTY          26985 non-null float64
# VALUE        26985 non-null float64
# PRICE        26985 non-null float64
# GRP          26985 non-null object
# SGRP         26985 non-null object
# SSGRP        26985 non-null object
# CMP          26985 non-null object
# MBRD         26985 non-null object
# BRD          26985 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
ideal_data['VALUE']=ideal_data['VALUE'].astype('int64')

# %%
X=ideal_data.drop("VALUE",axis=1)
Y=ideal_data['VALUE']

# %%
ideal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14260 entries, 0 to 14259
# Data columns (total 4 columns):
# MONTH        14260 non-null object
# STORECODE    14260 non-null object
# VALUE        14260 non-null int64
# GRP          14260 non-null object
# dtypes: int64(1), object(3)
# memory usage: 445.8+ KB

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
work_data
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0      M1    N1        4    T375    225.0     1.0  225.0  225.0
# 1      M1    N1        4    T379    95.0      1.0  95.0   95.0
# 2      M1    N1        4    T381    10.0      1.0  10.0   10.0
# 3      M1    N1        4    T382    108.0     1.0  108.0  108.0
# 4      M1    N1        4    T384    19.0      1.0  19.0   19.0
# ...    ..    ..       ..     ...     ...      ...   ...    ...
# 26980  M3    N10       31   T5999   10.0      1.0  10.0   10.0
# 26981  M3    N10       31   T6007   88.0      1.0  10.0   10.0
# 26982  M3    N10       31   T6007   88.0      2.0  20.0   10.0
# 26983  M3    N10       31   T6007   88.0      1.0  58.0   58.0
# 26984  M3    N10       31   T6013   15.0      1.0  15.0   15.0
#
#                               GRP                     SGRP  \
# 0      BUTTER MARGR  (4/94)        BUTTER
# 1      CONFECTIONERY - ECLAIRS     CONFECTIONERY - ECLAIRS
# ...

# %%
#'SGRP','SSGRP','CMP','MBRD','BRD'
categorical_features=['MONTH','STORECODE','GRP']

# %%
'''!pip install catboost
# !pip install ipywidgets
# !pip install shap
#!pip install sklearn
# !jupyter nbextension enable --py widgetsnbextension'''
# Out:
# '!pip install catboost\n!pip install ipywidgets\n!pip install shap\n#!pip install sklearn\n!jupyter nbextension enable --py widgetsnbextension'

# %%
from catboost import CatBoostRegressor

# %%
modelcb = CatBoostRegressor(iterations=2000)
#categorical_var = X_train['SEX'],X_train['EDUCATION'],X_train['MARRIAGE']

# fit the model with the training data
modelcb.fit(X_train,Y_train,cat_features=categorical_features,plot=False)
print('\n Model Trainied')

# predict the target on the train dataset
predict_train = modelcb.predict(X_train)
print('\nTarget on train data',predict_train)
# Out:
# Learning rate set to 0.035547
# 0:	learn: 738.6956177	total: 162ms	remaining: 5m 24s
# 1:	learn: 734.8555599	total: 177ms	remaining: 2m 56s
# 2:	learn: 730.7354781	total: 200ms	remaining: 2m 13s
# 3:	learn: 726.0833833	total: 212ms	remaining: 1m 45s
# 4:	learn: 721.6786380	total: 221ms	remaining: 1m 28s
# 5:	learn: 718.1993047	total: 229ms	remaining: 1m 15s
# 6:	learn: 714.6746093	total: 237ms	remaining: 1m 7s
# 7:	learn: 711.5999321	total: 245ms	remaining: 1m
# 8:	learn: 708.9894598	total: 253ms	remaining: 55.9s
# 9:	learn: 705.9984717	total: 261ms	remaining: 51.9s
# 10:	learn: 703.9507753	total: 269ms	remaining: 48.7s
# 11:	learn: 701.8542398	total: 278ms	remaining: 46s
# 12:	learn: 698.2732155	total: 286ms	remaining: 43.7s
# 13:	learn: 695.8043249	total: 294ms	remaining: 41.7s
# 14:	learn: 692.6855880	total: 302ms	remaining: 40s
# 15:	learn: 691.0722821	total: 310ms	remaining: 38.5s
# 16:	learn: 688.3004905	total: 318ms	remaining: 37.1s
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
#score(Y_train,predict_train)
import sklearn.metrics as metrics
from math import sqrt

#rms = sqrt(mean_squared_error(Y_train,predict_train)

# %%
mse = metrics.mean_squared_error(Y_train,predict_train)
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 595.2887621972161

# %%
work_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
# MONTH        26985 non-null object
# STORECODE    26985 non-null object
# DAY          26985 non-null int64
# BILL_ID      26985 non-null object
# BILL_AMT     26985 non-null float64
# QTY          26985 non-null float64
# VALUE        26985 non-null float64
# PRICE        26985 non-null float64
# GRP          26985 non-null object
# SGRP         26985 non-null object
# SSGRP        26985 non-null object
# CMP          26985 non-null object
# MBRD         26985 non-null object
# BRD          26985 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 4 columns):
# ID           2430 non-null int64
# STORECODE    2430 non-null object
# MONTH        2430 non-null object
# GRP          2430 non-null object
# dtypes: int64(1), object(3)
# memory usage: 76.1+ KB

# %%
val_data.drop('ID',axis=1,inplace=True)
predict = modelcb.predict(val_data)

# %%
predict
# Out:
# array([2193.04038174,  299.40338129,  112.12735799, ...,  495.07197595,
#         176.19238404,  462.72088859])

# %%
'''from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
predict = scaler.fit_transform(predict.reshape(-1,1))'''
# Out:
# 'from sklearn.preprocessing import MinMaxScaler\n\nscaler = MinMaxScaler()\npredict = scaler.fit_transform(predict.reshape(-1,1))'

# %%
predict
# Out:
# array([2193.04038174,  299.40338129,  112.12735799, ...,  495.07197595,
#         176.19238404,  462.72088859])

# %%
pred=2.55*predict

# %%
pred=pred.round().astype('int64')
pred
# Out:
# array([5592,  763,  286, ..., 1262,  449, 1180], dtype=int64)

# %%
solv=pd.read_csv('solv1.csv')
solv['TOTALVALUE'] = pred
solv.to_csv('solv1.csv',index=False)

# %%
solv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 2 columns):
# ID            2430 non-null int64
# TOTALVALUE    2430 non-null int64
# dtypes: int64(2)
# memory usage: 38.1 KB

# %%
...........#solv.drop('VALUE', axis=1, inplace=True)
# Out:
#   File "<ipython-input-41-0bd1257f76bf>", line 1
#     ...........#solv.drop('VALUE', axis=1, inplace=True)
#          ^
# SyntaxError: invalid syntax

# %%
def rf(df, score):

    X_train, X_test, y_train, y_test = train_test(df)

    params = {'n_estimators': [400, 700, 1000],
              'max_features': ['sqrt', 'auto'],
              'min_samples_split': [2, 3],
              'min_samples_leaf': [1, 2, 3],
              'max_depth': [50, 100, None],
              'bootstrap': [True, False]}
}

    scorers = {'RMSE': make_scorer(rmse, greater_is_better=False),
               'MAE': make_scorer(mean_absolute_error, greater_is_better=False),
               'R2': make_scorer(r2_score)}

    cv = RepeatedKFold(n_splits=10, n_repeats=7)


    grid = GridSearchCV(estimator=RandomForestRegressor(random_state=random.seed(42)),
                              param_grid=params, 
                              verbose=1, 
                              cv=cv, 
                              n_jobs =-1, 
                              scoring=scorers, 
                              refit = score)

    grid = grid.fit(X_train, y_train)    

    print('Parameters used:', grid.best_params_)

    if score  == 'RMSE':
        print('RMSE score on train:', round(-1*grid.best_score_,4))
        print('RMSE score on test: ', round(-1*grid.score(X_test, y_test),4))

    elif score == 'R2':
        print('R Squared score on train:', round(grid.best_score_,4))
        print('R Squared score on test: ', round(grid.score(X_test, y_test),4))

    elif score == 'MAE':
        print('MAE score on train:', round(-1*grid.best_score_,4))
        print('MAE score on test: ', round(-1*grid.score(X_test, y_test),4))

# %% [markdown]
# # RF

# %%
...........from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

# %%
unique, counts = np.unique(work_data.GRP, return_counts=True)
dict(zip(unique, counts))

# %%
unique, counts = np.unique(val_data.GRP, return_counts=True)
dict(zip(unique, counts))

# %%
regressor = DecisionTreeRegressor(random_state=0)
cross_val_score(regressor, X_train, Y_train, cv=10)
